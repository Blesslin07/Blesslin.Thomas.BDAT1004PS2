# %% [markdown]
# Question 1
# Consider the following Python module:
# a = 0
# def b():
# global a
# a = c(a)
# def c(a):
# return a + 2
# After importing the module into the interpreter, you execute:
# >>> b()
# >>> b()
# >>> b()
# >>> a?
# What value is displayed when the last expression (a) is evaluated? Explain youranswer by indicating what happens in every executed statement.

# %% [markdown]
# Following steps explain what happens at each step:
# a = 0: This initializes a global variable equals to 0.
# def b(): This defines a function b.
#
# global a
# a = c(a): Here we call the function c(a) and assign the result to the global variable a.
#
# def c(a): This defines a function c that takes an argument a.
# return a + 2: The function c takes the argument a, adds 2 to it, and returns the result.
#
# If we execute the function b() three times:
# b(): Calls the function b. Inside b, it updates the global variable a to 2 by calling c(a) (c(0) = 0 + 2).
# b(): Calls b again. Inside b, it takes the current value of a (which is now 2) and calls c(a). So, c(2) returns 2 + 2, which updates a to 4.
# b(): Calls b once more. Inside b, it takes the current value of a (which is now 4) and calls c(a). So, c(4) returns 4 +
# The final value of a is 6.

# %% [markdown]
# Question 2
# Function fileLength(), given to you, takes the name of a file as input and returnsthe length of the file:
# >>> fileLength('midterm.py')
# 284
# >>> fileLength('idterm.py')
# Traceback (most recent call last):
#  File "<pyshell#34>", line 1, in <module>
#     fileLength('idterm.py')File "/Users/me/midterm.py", line 3, in fileLengthinfile = open(filename)
#     FileNotFoundError: [Errno 2] No such file or directory:'idterm.py'
#
#     As shown above, if the file cannot be found by the interpreter or if it cannot be readas a text file, an exception will be raised. Modify function fileLength() so that afriendly message is printed instead:
#
#     >>> fileLength('midterm.py')
#     358
#     >>> fileLength('idterm.py')
#     File idterm.py not found.

# %%
def fileLength(filename):
    try:
        with open(filename, 'r') as infile:
            length = 0
            for line in infile:
                length += len(line)
            return length
    except FileNotFoundError:
        print(f"File {filename} not found.")

# Test the modified function
file_length = fileLength('midterm.py')
if file_length is not None:
    print(file_length)
file_length = fileLength('idterm.py')
# Out:
# File midterm.py not found.
# File idterm.py not found.

# %% [markdown]
# Question 3
# Write a class named Marsupial that can be used as shown below:
# >>> m = Marsupial()
# >>> m.put_in_pouch('doll')
# >>> m.put_in_pouch('firetruck')
# >>> m.put_in_pouch('kitten')
# >>> m.pouch_contents()['doll', 'firetruck', 'kitten']
#
# Now write a class named Kangaroo as a subclass of Marsupial that inherits all theattributes of Marsupial and also:
# a. extends the Marsupial __init__ constructor to take, as input, thecoordinates x and y of the Kangaroo object,
# b. supports method jump that takes number values dx and dy as input andmoves the kangaroo by dx units along the x-axis and by dy units along the y-axis, and
# c. overloads the __str__ operator so it behaves as shown below.
#
# >>> k = Kangaroo(0,0)
# >>> print(k)
# I am a Kangaroo located at coordinates (0,0)
# >>> k.put_in_pouch('doll')>>> k.put_in_pouch('firetruck')
# >>> k.put_in_pouch('kitten')
# >>> k.pouch_contents()
# ['doll', 'firetruck', 'kitten']
# >>> k.jump(1,0)
# >>> k.jump(1,0)
# >>> k.jump(1,0)
# >>> print(k)I am a Kangaroo located at coordinates (3,0)

# %%
class Marsupial:
    def __init__(self):
        self.pouch = []
    def put_in_pouch(self, item):
        self.pouch.append(item)
    def pouch_contents(self):
        return self.pouch
class Kangaroo(Marsupial):
    def __init__(self, x, y):
        super().__init__()  # Call the constructor of the base class
        self.x = x
        self.y = y
    def jump(self, dx, dy):
        self.x += dx
        self.y += dy
    def __str__(self):
        return f"I am a Kangaroo located at coordinates ({self.x},{self.y})"
    
m = Marsupial()
m.put_in_pouch('doll')
m.put_in_pouch('firetruck')
m.put_in_pouch('kitten')
print(m.pouch_contents())  

k = Kangaroo(0, 0)
print(k) 

k.put_in_pouch('doll')
k.put_in_pouch('firetruck')
k.put_in_pouch('kitten')
print(k.pouch_contents())  

k.jump(1, 0)
k.jump(1, 0)
k.jump(1, 0)
print(k)
# Out:
# ['doll', 'firetruck', 'kitten']
# I am a Kangaroo located at coordinates (0,0)
# ['doll', 'firetruck', 'kitten']
# I am a Kangaroo located at coordinates (3,0)

# %% [markdown]
# Question 4
# Write function collatz() that takes a positive integer x as input and prints theCollatz sequence starting at x. A Collatz sequence is obtained by repeatedly applyingthis rule to the previous number x in the sequence:
#
# x = { 𝑥/2      𝑖𝑓 𝑥 𝑖𝑠 𝑒𝑣𝑒𝑛
#       3𝑥 + 1   𝑖𝑓 𝑥 𝑖𝑠 𝑜𝑑𝑑
#
# Your function should stop when the sequence gets to number 1. Yourimplementation must be recursive, without any loops.
# >> collatz(1)
# 1
# >>> collatz(10)
# 10
# 5
# 16
# 8
# 4
# 2
# 1

# %%
def collatz(x):# defining function collatz
    print(x)
    if x == 1:
        return
    elif x % 2 == 0:
        collatz(x // 2)
    else:
        collatz(3 * x + 1)

collatz(1)
print('\n') 
collatz(10)
# Out:
# 1
#
#
# 10
# 5
# 16
# 8
# 4
# 2
# 1

# %% [markdown]
# Question 5
# Write a recursive method binary() that takes a non-negative integer n and prints the binary representation of integer n.
# >>> binary(0)
# 0
# >>> binary(1)
# 1
# >>> binary(3)
# 11
# >>> binary(9)

# %%
def binary(n):
    if n > 1:
        binary(n // 2)  # Recursive call with integer division
    print(n % 2, end="")  # Print the remainder when divided by 2

# Test cases
binary(0)  # Output: 0
print()  # Print a newline for formatting
binary(1)  # Output: 1
print()
binary(3)  # Output: 11
print()
binary(9)  # Output: 1001
# Out:
# 0
# 1
# 11
# 1001

# %% [markdown]
# Question 8
# Write SQL queries on the below database table that return:
# a) All the temperature data.
# b) All the cities, but without repetition.
# c) All the records for India.
# d) All the Fall records
# e) The city, country, and season for which the average rainfall is between 200
# and 400 millimeters.
# f) The city and country for which the average Fall temperature is above 20
# degrees, in increasing temperature order.
# g) The total annual rainfall for Cairo.
# h) The total rainfall for each season.

# %%
import sqlite3

conn = sqlite3.connect('blesslin_thomas.db')
cursor = conn.cursor()

#cursor.execute('''
    #CREATE TABLE weather 
    #(City TEXT, Country TEXT, Season TEXT, "Temperature(C)" FLOAT, "Rainfall(mm)" FLOAT)
#''')

weather_data = [
    ('Mumbai', 'India', 'Winter', 24.8, 5.9),
    ('Mumbai', 'India', 'Spring', 28.4, 16.2),
    ('Mumbai', 'India', 'Summer', 27.9, 1549.4),
    ('Mumbai', 'India', 'Fall', 27.6, 346.0),
    ('London', 'United Kingdom', 'Winter', 4.2, 207.7),
    ('London', 'United Kingdom', 'Spring', 8.3, 169.6),
    ('London', 'United Kingdom', 'Summer', 15.7, 157.0),
    ('London', 'United Kingdom', 'Fall', 10.4, 218.5),
    ('Cairo', 'Egypt', 'Winter', 13.6, 16.5),
    ('Cairo', 'Egypt', 'Spring', 20.7, 6.5),
    ('Cairo', 'Egypt', 'Summer', 27.7, 0.1),
    ('Cairo', 'Egypt', 'Fall', 22.2, 4.5)
]
"""
cursor.executemany('''
    INSERT INTO weather (City, Country, Season, "Temperature(C)", "Rainfall(mm)")
    VALUES (?, ?, ?, ?, ?)
''', weather_data)
"""

# a) All the temperature data.
cursor.execute('SELECT "Temperature(C)" FROM weather')
temperature_data = cursor.fetchall()
print("a) All Temperature Data:", temperature_data)
print("============================================")

#b) All the cities, but without repetition.
cursor.execute('SELECT DISTINCT City FROM weather')
unique_cities = cursor.fetchall()
print("b) All Unique Cities:", unique_cities)
print("============================================")

#c) All the records for India.
cursor.execute('SELECT * FROM weather WHERE Country = "India"')
india_records = cursor.fetchall()
print("c) Records for India:", india_records)
print("==============================================")

#d) All the Fall records
cursor.execute('SELECT * FROM weather WHERE Season = "Fall"')
fall_records = cursor.fetchall()
print("d) Fall Records:", fall_records)
print("=================================================")

#e) The city, country, and season for which the average rainfall is between 200 and 400 millimeters.
cursor.execute('''
    SELECT City, Country, Season
    FROM weather
    GROUP BY City, Country, Season
    HAVING AVG("Rainfall(mm)") BETWEEN 200 AND 400
''')
rainfall = cursor.fetchall()
print("e) Average Rainfall between 200 and 400:", rainfall)
print("=============================================")

#f) The city and country for which the average Fall temperature is above 20 degrees, in increasing temperature order.
cursor.execute('''
    SELECT City, Country
    FROM weather
    WHERE Season = "Fall"
    GROUP BY City, Country
    HAVING AVG("Temperature(C)") > 20
    ORDER BY AVG("Temperature(C)") ASC
''')
highTemp_cities= cursor.fetchall()
print("f) High-Temperature Cities in Fall:", highTemp_cities)
print("=================================================")

#g) The total annual rainfall for Cairo.
cursor.execute('SELECT SUM("Rainfall(mm)") AS "Total Rainfall" FROM weather WHERE City = "Cairo"')
cairo_total_rainfall = cursor.fetchone()[0]
print("g) Total Rainfall for Cairo:", cairo_total_rainfall)
print("=====================================================")

#h) The total rainfall for each season.
cursor.execute('SELECT Season, SUM("Rainfall(mm)") AS "Total Rainfall" FROM weather GROUP BY Season')
total_rainfall= cursor.fetchall()
print("h) Total Rainfall by Season:", total_rainfall)
print("=========================================================")

conn.commit()
conn.close()
# Out:
# a) All Temperature Data: [(24.8,), (28.4,), (27.9,), (27.6,), (4.2,), (8.3,), (15.7,), (10.4,), (13.6,), (20.7,), (27.7,), (22.2,), (24.8,), (28.4,), (27.9,), (27.6,), (4.2,), (8.3,), (15.7,), (10.4,), (13.6,), (20.7,), (27.7,), (22.2,), (24.8,), (28.4,), (27.9,), (27.6,), (4.2,), (8.3,), (15.7,), (10.4,), (13.6,), (20.7,), (27.7,), (22.2,), (24.8,), (28.4,), (27.9,), (27.6,), (4.2,), (8.3,), (15.7,), (10.4,), (13.6,), (20.7,), (27.7,), (22.2,), (24.8,), (28.4,), (27.9,), (27.6,), (4.2,), (8.3,), (15.7,), (10.4,), (13.6,), (20.7,), (27.7,), (22.2,)]
# ...
# b) All Unique Cities: [('Mumbai',), ('London',), ('Cairo',)]
# ...

# %% [markdown]
# Question 9
# . Suppose list words is defined as follows:
# >>> words = ['The', 'quick', 'brown', 'fox', 'jumps', 'over',
# 'the', 'lazy', 'dog']
# Write list comprehension expressions that use list words and generate the following
# lists:
# a) ['THE', 'QUICK', 'BROWN', 'FOX', 'JUMPS', 'OVER', 'THE',
# 'LAZY', 'DOG']
# b) ['the', 'quick', 'brown', 'fox', 'jumps', 'over', 'the',
# 'lazy', 'dog']
# c) [3, 5, 5, 3, 5, 4, 3, 4, 3] (the list of lengths of words in list
# words).
# d) [['THE', 'the', 3], ['QUICK', 'quick', 5], ['BROWN',
# 'brown', 5], ['FOX', 'fox', 3], ['JUMPS', 'jumps', 5],
# ['OVER', 'over', 4], ['THE', 'the', 3], ['LAZY', 'lazy',
# 4], ['DOG', 'dog', 3]] (the list containing a list for every word of list
# words, where each list contains the word in uppercase and lowercase and the
# length of the word.)
# e) ['The', 'quick', 'brown', 'fox', 'jumps', 'over', 'the',
# 'lazy', 'dog'] (the list of words in list words containing 4 or more
# characters.

# %%
words = ['The', 'quick', 'brown', 'fox', 'jumps', 'over', 
'the', 'lazy', 'dog']

#a)upper case words
uppercase_words = [word.upper() for word in words]
print("a) ",uppercase_words)

#b)lower case words
lowercase_words = [word.lower() for word in words]
print("b) ",lowercase_words)

#c)the list of lengths of words in list words
word_lengths = [len(word) for word in words]
print("c) ",word_lengths)

#d)the list containing a list for every word of list words, where each 
#list contains the word in uppercase and lowercase and the length of the word.
word_info = [[word.upper(), word.lower(), len(word)] for word in words]
print("d) ",word_info)

#e)the list of words in list words containing 4 or more characters.
long_words = [word for word in words if len(word)>= 4]
print("e) ",long_words)
# Out:
# ['The', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']
# a)  ['THE', 'QUICK', 'BROWN', 'FOX', 'JUMPS', 'OVER', 'THE', 'LAZY', 'DOG']
# b)  ['the', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']
# c)  [3, 5, 5, 3, 5, 4, 3, 4, 3]
# d)  [['THE', 'the', 3], ['QUICK', 'quick', 5], ['BROWN', 'brown', 5], ['FOX', 'fox', 3], ['JUMPS', 'jumps', 5], ['OVER', 'over', 4], ['THE', 'the', 3], ['LAZY', 'lazy', 4], ['DOG', 'dog', 3]]
# e)  ['quick', 'brown', 'jumps', 'over', 'lazy']
